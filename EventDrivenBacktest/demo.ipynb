# %%
from dotenv import load_dotenv
load_dotenv()
import os
import sys
sys.path.append(
    os.environ.get('WORK_DIR')) #type: ignore
sys.path.append(
    os.environ.get('DBASE_DIR')) #type: ignore
import importlib
from dbase.DataAPI.ThetaData import * #type: ignore
from dbase.database.SQLHelpers import * #type: ignore
import pandas as pd
from data import HistoricTradeDataHandler
from event import *
from strategy import OptionSignalStrategy
from portfolio import OptionSignalPortfolio
from execution import SimulatedExecutionHandler
from queue import Queue
from trade.backtester_.backtester_ import PTDataset, PTBacktester
import pandas_ta as ta
from trade.assets.Stock import Stock
from trade.backtester_.utils.WalkForwardUtils import prev_monday
from trade.backtester_.strats import BBandsTrend2
import yfinance as yf
from datetime import datetime
from backtest import OptionSignalBacktest
# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 13
#      11 from dbase.database.SQLHelpers import * #type: ignore
#      12 import pandas as pd
# ---> 13 from data import HistoricTradeDataHandler
#      14 from event import *
#      15 from strategy import OptionSignalStrategy
#
# File ~/Documents/GitHub/stop-loss-script/BACKTEST/event_driven/data.py:13
#      10 sys.path.append(
#      11     os.environ.get('DBASE_DIR')) #type: ignore
#      12 from dbase.database.SQLHelpers import query_database # type: ignore
# ---> 13 from dbase.DataAPI.ThetaData import retrieve_option_ohlc # type: ignore
#      14 from abc import ABCMeta, abstractmethod
#      16 from BACKTEST.event_driven.event import MarketEvent
#
# ImportError: cannot import name 'retrieve_option_ohlc' from 'dbase.DataAPI.ThetaData' (/Users/chiemelienwanisobi/cloned_repos/FinanceDatabase/dbase/DataAPI/ThetaData.py)

# %%
def create_datasate(stocks: list, start: str,interval: str, engine: str = 'yf', timewidth = None, timeframe = None, end: str = datetime.today(), return_object = False ):
    dataset = []
    if engine.lower() == 'yf':
        for stock in stocks:
            start = prev_monday(start)
            data2 = yf.download(stock, start = start, end = end, interval=interval, progress = False)

            dataset.append(PTDataset(stock, data2))
    else:
        for stk in stocks:
            stock = Stock(stk)
            data = stock.spot(ts = True, ts_start = '2018-01-01')
            data.rename(columns = {x:x.capitalize() for x in data.columns}, inplace= True)
            data['Timestamp'] = pd.to_datetime(data['Timestamp'], format = '%Y-%m-%d')
            data2 = data.set_index('Timestamp')
            data2 = data2.asfreq('W', method = 'ffill')
            data2 = data2.fillna(0)
            data2['Next_Day_Open'] = data2.Open.shift(-1)
            data2['EMA'] = ta.ma('ema', data2.Close, length = 21).fillna(0)
            dataset.append(PTDataset(stk, data2))
    return dataset if return_object else data2

# %%
start, end, interval = '2023-05-29', '2024-05-28','1d'
STOCKS = ['AAPL', 'MSFT','GOOGL', 'AMD', 'AMZN']
dataset = create_datasate(STOCKS, start, interval,end = end , return_object=True)
BBandsTrend2.start_date = pd.to_datetime('1994-03-22')
tt = PTBacktester(dataset, BBandsTrend2, cash =1000, commission = 0.0035)
stats = tt.run()
trades = tt.trades()
trades
# Out:
#    Size  EntryBar  ExitBar  EntryPrice   ExitPrice         PnL  ReturnPct  \
# 0     4       191      202  205.878064  182.375999  -94.008257  -0.114155
# 0     2       191      232  414.887042  392.609985  -44.554114  -0.053694
# 0     5       191      249  178.151354  181.649994   17.493201   0.019639
# 0     7       197      249  137.509604  174.979996  262.292744   0.272493
# 1     4       203      219  182.667104  163.277998  -77.556422  -0.106144
# 2     5       220      224  165.005498  146.951999  -90.267494  -0.109411
# 3     4       230      233  159.636782  145.509995  -56.507149  -0.088493
# 1     2       233      249  399.051814  427.190002   56.276378   0.070513
# 4     4       236      237  156.867127  153.399994  -13.868534  -0.022102
# 0     5       241      249  188.166279  188.820007    3.268639   0.003474
# 5     4       243      249  161.483218  161.410004   -0.292858  -0.000453
#
#    EntryTime   ExitTime   Tag Duration Ticker
# 0 2024-03-04 2024-03-19  None  15 days    AMD
# 0 2024-03-04 2024-05-01  None  58 days   MSFT
# 0 2024-03-04 2024-05-24  None  81 days   AMZN
# 0 2024-03-12 2024-05-24  None  73 days  GOOGL
# 1 2024-03-20 2024-04-12  None  23 days    AMD
# 2 2024-04-15 2024-04-19  None   4 days    AMD
# 3 2024-04-29 2024-05-02  None   3 days    AMD
# 1 2024-05-02 2024-05-24  None  22 days   MSFT
# 4 2024-05-07 2024-05-08  None   1 days    AMD
# 0 2024-05-14 2024-05-24  None  10 days   AAPL
# 5 2024-05-16 2024-05-24  None   8 days    AMD

# %%
equity = tt.pf_value_ts()
equity
# Out:
#                    AAPL         MSFT        GOOGL          AMD         AMZN  \
# 2023-05-30  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# 2023-05-31  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# 2023-06-01  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# 2023-06-02  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# 2023-06-05  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# ...                 ...          ...          ...          ...          ...
# 2024-05-20  1014.368569  1008.022251  1275.872761   687.179279  1026.943198
# 2024-05-21  1020.918633  1015.422276  1282.382816   680.499287  1024.993201
# 2024-05-22  1013.668572  1018.382236  1272.092808   683.939289  1024.893256
# 2024-05-23   993.568627  1011.342258  1252.282795   663.579243  1014.493246
# 2024-05-24  1003.268639  1011.722263  1262.292744   667.499287  1017.493201
#
#                   Total
# 2023-05-30  5000.000000
# 2023-05-31  5000.000000
# 2023-06-01  5000.000000
# 2023-06-02  5000.000000
# 2023-06-05  5000.000000
# ...                 ...
# 2024-05-20  5012.386058
# 2024-05-21  5024.216212
# 2024-05-22  5012.976161
# 2024-05-23  4935.266169
# 2024-05-24  4962.276133
#
# [250 rows x 6 columns]

# %%
#Backtest class
evb_backtest = OptionSignalBacktest(trades)

# %%
signals = evb_backtest.bars.signal_df
signals
# Out:
#          Date  AMD  MSFT  AMZN  GOOGL  AAPL
# 0  2024-03-04    1     1     1      0     0
# 1  2024-03-05    0     0     0      0     0
# 2  2024-03-06    0     0     0      0     0
# 3  2024-03-07    0     0     0      0     0
# 4  2024-03-08    0     0     0      0     0
# ..        ...  ...   ...   ...    ...   ...
# 77 2024-05-20    0     0     0      0     0
# 78 2024-05-21    0     0     0      0     0
# 79 2024-05-22    0     0     0      0     0
# 80 2024-05-23    0     0     0      0     0
# 81 2024-05-24   -1    -1    -1     -1    -1
#
# [82 rows x 6 columns]

# %%
#run backtest
evb_backtest.run()
# Out:
# exception occured:
#          Date  AMD  MSFT  AMZN  GOOGL  AAPL
# 71 2024-05-14    0     0     0      0     1
# event  MARKET
# event  SIGNAL
# event  ORDER
# event  FILL
# 2024-11-03 17:37:53 OptionSignalBacktest ERROR: exception occured:
# exception occured:
#          Date  AMD  MSFT  AMZN  GOOGL  AAPL
# 72 2024-05-15    0     0     0      0     0
# event  MARKET
# 2024-11-03 17:37:53 OptionSignalBacktest ERROR: exception occured:
# exception occured:
#          Date  AMD  MSFT  AMZN  GOOGL  AAPL
# 73 2024-05-16    1     0     0      0     0
# event  MARKET
# event  SIGNAL
# event  ORDER
# event  FILL
# 2024-11-03 17:37:55 OptionSignalBacktest ERROR: exception occured:
# exception occured:
#          Date  AMD  MSFT  AMZN  GOOGL  AAPL
# 74 2024-05-17    0     0     0      0     0
# event  MARKET
# 2024-11-03 17:37:55 OptionSignalBacktest ERROR: exception occured:
# exception occured:
#          Date  AMD  MSFT  AMZN  GOOGL  AAPL
# 75 2024-05-18    0     0     0      0     0
# event  MARKET
# 2024-11-03 17:37:55 OptionSignalBacktest ERROR: exception occured:
# exception occured:
#          Date  AMD  MSFT  AMZN  GOOGL  AAPL
# 76 2024-05-19    0     0     0      0     0
# event  MARKET
# 2024-11-03 17:37:55 OptionSignalBacktest ERROR: exception occured:
# exception occured:
#          Date  AMD  MSFT  AMZN  GOOGL  AAPL
# 77 2024-05-20    0     0     0      0     0
# event  MARKET
# 2024-11-03 17:37:55 OptionSignalBacktest ERROR: exception occured:
# exception occured:
#          Date  AMD  MSFT  AMZN  GOOGL  AAPL
# 78 2024-05-21    0     0     0      0     0
# event  MARKET
# 2024-11-03 17:37:55 OptionSignalBacktest ERROR: exception occured:
# exception occured:
#          Date  AMD  MSFT  AMZN  GOOGL  AAPL
# 79 2024-05-22    0     0     0      0     0
# event  MARKET
# 2024-11-03 17:37:55 OptionSignalBacktest ERROR: exception occured:
# exception occured:
#          Date  AMD  MSFT  AMZN  GOOGL  AAPL
# 80 2024-05-23    0     0     0      0     0
# event  MARKET
# 2024-11-03 17:37:55 OptionSignalBacktest ERROR: exception occured:
# exception occured:
#          Date  AMD  MSFT  AMZN  GOOGL  AAPL
# 81 2024-05-24   -1    -1    -1     -1    -1
# event  MARKET
# event  SIGNAL
# event  SIGNAL
# event  SIGNAL
# event  SIGNAL
# event  SIGNAL
# event  ORDER
# event  ORDER
# event  ORDER
# event  ORDER
# event  ORDER
# event  FILL
# event  FILL
# event  FILL
# event  FILL
# event  FILL
# 2024-11-03 17:37:55 OptionSignalBacktest ERROR: exception occured:
# exception occured:
# No more signals available
#          Date  AMD  MSFT  AMZN  GOOGL  AAPL
# 81 2024-05-24   -1    -1    -1     -1    -1
# event  MARKET
# event  SIGNAL
# event  SIGNAL
# event  SIGNAL
# event  SIGNAL
# event  SIGNAL
# event  ORDER
# event  ORDER
# event  ORDER
# event  ORDER
# event  ORDER
# event  FILL
# event  FILL
# event  FILL
# event  FILL
# event  FILL
# 2024-11-03 17:37:55 OptionSignalBacktest ERROR: exception occured:
# exception occured:
# no more data to feed backtest

# %%
trades = evb_backtest.portfolio.get_trades()
print(trades.to_string())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In
# 2024-05-14                  None                   None  MSFT-20241115-450.0-C  GOOGL-20241220-175.0-C
# 2024-05-15                  None  AAPL-20241220-210.0-C  MSFT-20241115-450.0-C  GOOGL-20241220-175.0-C
# 2024-05-16                  None  AAPL-20241220-210.0-C  MSFT-20241115-450.0-C  GOOGL-20241220-175.0-C
# 2024-05-17  AMD-20250117-220.0-C  AAPL-20241220-210.0-C  MSFT-20241115-450.0-C  GOOGL-20241220-175.0-C
# 2024-05-20  AMD-20250117-220.0-C  AAPL-20241220-210.0-C  MSFT-20241115-450.0-C  GOOGL-20241220-175.0-C
# 2024-05-21  AMD-20250117-220.0-C  AAPL-20241220-210.0-C  MSFT-20241115-450.0-C  GOOGL-20241220-175.0-C
# 2024-05-22  AMD-20250117-220.0-C  AAPL-20241220-210.0-C  MSFT-20241115-450.0-C  GOOGL-20241220-175.0-C
# 2024-05-23  AMD-20250117-220.0-C  AAPL-20241220-210.0-C  MSFT-20241115-450.0-C  GOOGL-20241220-175.0-C
# 2024-05-24  AMD-20250117-220.0-C  AAPL-20241220-210.0-C  MSFT-20241115-450.0-C  GOOGL-20241220-175.0-C
# 2024-05-24                  None                   None                   None                    None

# %%
evb_backtest.portfolio.all_positions
# Out:
# [{'AMD': {'quantity': 0.0, 'option': None},
#   'MSFT': {'quantity': 0.0, 'option': None},
#   'AMZN': {'quantity': 0.0, 'option': None},
#   'GOOGL': {'quantity': 0.0, 'option': None},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-04 00:00:00')},
#  {'AMD': {'quantity': 0.0, 'option': None},
#   'MSFT': {'quantity': 0.0, 'option': None},
#   'AMZN': {'quantity': 0.0, 'option': None},
#   'GOOGL': {'quantity': 0.0, 'option': None},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-04 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20240920-240.0-C',
#    'entry_price': 2185.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 0.0, 'option': None},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-05 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20240920-240.0-C',
#    'entry_price': 2185.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 0.0, 'option': None},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-06 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20240920-240.0-C',
#    'entry_price': 2185.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 0.0, 'option': None},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-07 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20240920-240.0-C',
#    'entry_price': 2185.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 0.0, 'option': None},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-08 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20240920-240.0-C',
#    'entry_price': 2185.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 0.0, 'option': None},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-11 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20240920-240.0-C',
#    'entry_price': 2185.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 0.0, 'option': None},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-12 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20240920-240.0-C',
#    'entry_price': 2185.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-13 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20240920-240.0-C',
#    'entry_price': 2185.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-14 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20240920-240.0-C',
#    'entry_price': 2185.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-15 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20240920-240.0-C',
#    'entry_price': 2185.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-18 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20240920-240.0-C',
#    'entry_price': 2185.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-19 00:00:00')},
#  {'AMD': {'quantity': -2,
#    'option': 'AMD-20240920-240.0-C',
#    'exit_price': 931.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-20 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-21 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-22 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-25 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-26 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-27 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-28 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-03-29 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-01 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-02 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-03 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-04 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-05 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-08 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-09 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-10 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-11 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20250117-220.0-C',
#    'entry_price': 1870.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-12 00:00:00')},
#  {'AMD': {'quantity': -2,
#    'option': 'AMD-20250117-220.0-C',
#    'exit_price': 1247.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-15 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241018-220.0-C',
#    'entry_price': 725.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-16 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241018-220.0-C',
#    'entry_price': 725.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-17 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241018-220.0-C',
#    'entry_price': 725.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-18 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241018-220.0-C',
#    'entry_price': 725.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-19 00:00:00')},
#  {'AMD': {'quantity': -2,
#    'option': 'AMD-20241018-220.0-C',
#    'exit_price': 413.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-22 00:00:00')},
#  {'AMD': {'quantity': -2,
#    'option': 'AMD-20241018-220.0-C',
#    'exit_price': 413.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-23 00:00:00')},
#  {'AMD': {'quantity': -2,
#    'option': 'AMD-20241018-220.0-C',
#    'exit_price': 413.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-24 00:00:00')},
#  {'AMD': {'quantity': -2,
#    'option': 'AMD-20241018-220.0-C',
#    'exit_price': 413.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-25 00:00:00')},
#  {'AMD': {'quantity': -2,
#    'option': 'AMD-20241018-220.0-C',
#    'exit_price': 413.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-26 00:00:00')},
#  {'AMD': {'quantity': -2,
#    'option': 'AMD-20241018-220.0-C',
#    'exit_price': 413.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-29 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241220-200.0-C',
#    'entry_price': 1325.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-04-30 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241220-200.0-C',
#    'entry_price': 1325.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20250117-540.0-C',
#    'entry_price': 778.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-05-01 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241220-200.0-C',
#    'entry_price': 1325.0},
#   'MSFT': {'quantity': -2,
#    'option': 'MSFT-20250117-540.0-C',
#    'exit_price': 0.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-05-02 00:00:00')},
#  {'AMD': {'quantity': -2,
#    'option': 'AMD-20241220-200.0-C',
#    'exit_price': 750.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-05-03 00:00:00')},
#  {'AMD': {'quantity': -2,
#    'option': 'AMD-20241220-200.0-C',
#    'exit_price': 750.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-05-06 00:00:00')},
#  {'AMD': {'quantity': -2,
#    'option': 'AMD-20241220-200.0-C',
#    'exit_price': 750.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-05-07 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241220-185.0-C',
#    'entry_price': 1385.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-05-08 00:00:00')},
#  {'AMD': {'quantity': -2, 'option': 'AMD-20241220-185.0-C', 'exit_price': 0.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-05-09 00:00:00')},
#  {'AMD': {'quantity': -2, 'option': 'AMD-20241220-185.0-C', 'exit_price': 0.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-05-10 00:00:00')},
#  {'AMD': {'quantity': -2, 'option': 'AMD-20241220-185.0-C', 'exit_price': 0.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-05-13 00:00:00')},
#  {'AMD': {'quantity': -2, 'option': 'AMD-20241220-185.0-C', 'exit_price': 0.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 0.0, 'option': None},
#   'datetime': Timestamp('2024-05-14 00:00:00')},
#  {'AMD': {'quantity': -2, 'option': 'AMD-20241220-185.0-C', 'exit_price': 0.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 2,
#    'option': 'AAPL-20250117-215.0-C',
#    'entry_price': 487.0},
#   'datetime': Timestamp('2024-05-15 00:00:00')},
#  {'AMD': {'quantity': -2, 'option': 'AMD-20241220-185.0-C', 'exit_price': 0.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 2,
#    'option': 'AAPL-20250117-215.0-C',
#    'entry_price': 487.0},
#   'datetime': Timestamp('2024-05-16 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241220-210.0-C',
#    'entry_price': 1115.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 2,
#    'option': 'AAPL-20250117-215.0-C',
#    'entry_price': 487.0},
#   'datetime': Timestamp('2024-05-17 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241220-210.0-C',
#    'entry_price': 1115.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 2,
#    'option': 'AAPL-20250117-215.0-C',
#    'entry_price': 487.0},
#   'datetime': Timestamp('2024-05-20 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241220-210.0-C',
#    'entry_price': 1115.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 2,
#    'option': 'AAPL-20250117-215.0-C',
#    'entry_price': 487.0},
#   'datetime': Timestamp('2024-05-21 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241220-210.0-C',
#    'entry_price': 1115.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 2,
#    'option': 'AAPL-20250117-215.0-C',
#    'entry_price': 487.0},
#   'datetime': Timestamp('2024-05-22 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241220-210.0-C',
#    'entry_price': 1115.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 2,
#    'option': 'AAPL-20250117-215.0-C',
#    'entry_price': 487.0},
#   'datetime': Timestamp('2024-05-23 00:00:00')},
#  {'AMD': {'quantity': 2,
#    'option': 'AMD-20241220-210.0-C',
#    'entry_price': 1115.0},
#   'MSFT': {'quantity': 2,
#    'option': 'MSFT-20241018-440.0-C',
#    'entry_price': 1190.0},
#   'AMZN': {'quantity': 2,
#    'option': 'AMZN-20250321-205.0-C',
#    'entry_price': 0.0},
#   'GOOGL': {'quantity': 2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'entry_price': 1450.0},
#   'AAPL': {'quantity': 2,
#    'option': 'AAPL-20250117-215.0-C',
#    'entry_price': 487.0},
#   'datetime': Timestamp('2024-05-24 00:00:00')},
#  {'AMD': {'quantity': -2,
#    'option': 'AMD-20241220-210.0-C',
#    'exit_price': 1025.0},
#   'MSFT': {'quantity': -2,
#    'option': 'MSFT-20241018-440.0-C',
#    'exit_price': 2180.0},
#   'AMZN': {'quantity': -2,
#    'option': 'AMZN-20250321-205.0-C',
#    'exit_price': 0.0},
#   'GOOGL': {'quantity': -2,
#    'option': 'GOOGL-20250620-155.0-C',
#    'exit_price': 0.0},
#   'AAPL': {'quantity': -2,
#    'option': 'AAPL-20250117-215.0-C',
#    'exit_price': 565.0},
#   'datetime': Timestamp('2024-05-24 00:00:00')}]

# %%
from pprint import pprint

print('All positions:')
pprint(portfolio.all_positions)

print('\nCurrent holdings:')
pprint(portfolio.current_holdings)

print('\nCurrent positions:')
pprint(portfolio.current_positions)
# Out:
# All positions:
# [{'AAPL': {'option': None, 'quantity': 0.0},
#   'AMD': {'option': None, 'quantity': 0.0},
#   'AMZN': {'option': None, 'quantity': 0.0},
#   'GOOGL': {'option': None, 'quantity': 0.0},
#   'MSFT': {'option': None, 'quantity': 0.0},
#   'datetime': '20240226'},
#  {'AAPL': {'option': None, 'quantity': 0.0},
#   'AMD': {'option': None, 'quantity': 0.0},
#   'AMZN': {'option': None, 'quantity': 0.0},
#   'GOOGL': {'option': None, 'quantity': 0.0},
#   'MSFT': {'option': None, 'quantity': 0.0},
#   'datetime': Timestamp('2024-02-26 00:00:00')},
#  {'AAPL': {'option': None, 'quantity': 0.0},
#   'AMD': {'option': None, 'quantity': 0.0},
#   'AMZN': {'option': None, 'quantity': 0.0},
#   'GOOGL': {'option': None, 'quantity': 0.0},
#   'MSFT': {'option': None, 'quantity': 0.0},
#   'datetime': Timestamp('2024-02-26 00:00:00')}]
#
# Current holdings:
# {'AAPL': 0.0,
#  'AMD': 0.0,
#  'AMZN': 0.0,
#  'GOOGL': 0.0,
#  'MSFT': 0.0,
#  'cash': 100000,
#  'commission': 0.0,
#  'total': 100000}
#
# Current positions:
# {'AAPL': {'option': None, 'quantity': 0.0},
#  'AMD': {'option': None, 'quantity': 0.0},
#  'AMZN': {'option': None, 'quantity': 0.0},
#  'GOOGL': {'option': None, 'quantity': 0.0},
#  'MSFT': {'option': None, 'quantity': 0.0}}

# %%
def generate_option_to_buy(underlier: Stock, contract_time):
        """
        Buy an option based on the underlier.
        """
        time = contract_time
        next_day_time = time + pd.DateOffset(days=1)
        print(time, next_day_time)
        option_spot = underlier.spot(ts=True, ts_start = time, ts_end = next_day_time)
        option_spot = option_spot.iloc[0] 
        stock_price = option_spot['open']#use open price as spot price on the assumption of making trades at start of day
        oom_benchmark = 0.1#10% out of the money 
        expiry_benchmark = time + pd.DateOffset(months=5)
        oom_price = stock_price * (1 + oom_benchmark)
        time_str = time.strftime("%Y%m%d")
        contracts = list_contracts(underlier.ticker, time_str)
        print(contracts)
        contracts = contracts[contracts['right'] == 'C'] 
        
        
        #Filter out contracts that are out of the money
        contracts = contracts[contracts['strike'] >= oom_price]
        
        print('comparing expiry')
        print(type(expiry_benchmark))
        print(type(contracts['expiration']))
        #filter out contracts that are  below the expiry benchmark
        contracts = contracts[pd.to_datetime(contracts['expiration'], format="%Y%m%d") >= expiry_benchmark]
        
        #select a random contract to buy
        contract = contracts.sample(n=1); 
        
        return contract

# %%
appl = Stock('AAPL')
c_time = pd.to_datetime('2024-05-06', format="%Y-%m-%d")
c_time_next = c_time + pd.DateOffset(days=1)
aapl_spot = appl.spot(ts=True, ts_start = c_time, ts_end = c_time_next)
aapl_spot.iloc[0]['open']
# Out:
# 182.35000610351562

# %%
option = generate_option_to_buy(appl, c_time)
option
# Out:
# 2024-05-06 00:00:00 2024-05-07 00:00:00
#       root  expiration  strike right
# 0     AAPL    20241018   220.0     C
# 1     AAPL    20250919   215.0     C
# 2     AAPL    20241115   220.0     C
# 3     AAPL    20250321   220.0     C
# 4     AAPL    20250321   220.0     P
# ...    ...         ...     ...   ...
# 1060  AAPL    20240621   220.0     C
# 1061  AAPL    20240621   220.0     P
# 1062  AAPL    20240719   220.0     C
# 1063  AAPL    20250620   215.0     C
# 1064  AAPL    20240816   220.0     C
#
# [1065 rows x 4 columns]
# comparing expiry
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas.core.series.Series'>
#      root  expiration  strike right
# 456  AAPL    20250117   235.0     C

# %%
list_contracts('MSFT', '20240304')
# Out:
#       root  expiration  strike right
# 0     MSFT    20250620   610.0     C
# 1     MSFT    20240621   485.0     C
# 2     MSFT    20240621   355.0     P
# 3     MSFT    20240621   355.0     C
# 4     MSFT    20240719   355.0     C
# ...    ...         ...     ...   ...
# 1307  MSFT    20250117   610.0     C
# 1308  MSFT    20250117   480.0     C
# 1309  MSFT    20240315   485.0     C
# 1310  MSFT    20261218   600.0     C
# 1311  MSFT    20251219   475.0     C
#
# [1312 rows x 4 columns]

# %%
eod= retrieve_option_ohlc('AMD', exp = '20250117', strike=240.0, right = 'C', start_date = '20240304', end_date = '20250117')
print(eod)
# Out:
#      ms_of_day   open   high    low  close  volume  count       date
# 5     52200000  30.65  30.65  30.65  30.65       1      1 2024-03-04
# 11    52200000   0.00   0.00   0.00   0.00       0      0 2024-03-05
# 17    52200000  31.95  31.95  30.93  30.93       5      5 2024-03-06
# 23    52200000  33.24  33.24  32.08  32.20       5      4 2024-03-07
# 29    52200000  31.92  31.92  31.38  31.60       3      3 2024-03-08
# ..         ...    ...    ...    ...    ...     ...    ...        ...
# 929   52200000   1.38   1.38   1.38   1.38       1      1 2024-10-14
# 935   52200000   0.85   0.85   0.85   0.85      10      1 2024-10-15
# 941   52200000   0.00   0.00   0.00   0.00       0      0 2024-10-16
# 947   52200000   0.83   0.83   0.83   0.83       5      2 2024-10-17
# 953   52200000   0.73   0.73   0.73   0.73       1      1 2024-10-18
#
# [159 rows x 8 columns]

# %%
import requests
url = "http://127.0.0.1:25510/v2/hist/option/ohlc"
querystring = {"end_date":'20241020', "root": 'AMD', "use_csv": "true", "exp": '20250117', "ivl": 3600000, "right": 'C', "start_date": '20240304', "strike": 240.0 * 1000}
headers = {"Accept": "application/json"}
response = requests.get(url, headers=headers, params=querystring)
print(response.status_code, response.text, )
# Out:
# 473 For input string

# %%
import pandas as pd
options = [{'AMD': {'quantity': 2, 'option': 'AMD-20240816-270.0-C', 'entry_price': 120},
  'MSFT': {'quantity': 2, 'option': 'MSFT-20240816-480.0-C'},
  'AMZN': {'quantity': 2, 'option': 'AMZN-20250321-205.0-C'},
  'GOOGL': {'quantity': 0.0, 'option': None},
  'AAPL': {'quantity': 0.0, 'option': None},
  'datetime': '2024-03-05',},
 {'AMD': {'quantity': 2, 'option': 'AMD-20240816-270.0-C', 'entry_price': 140},
  'MSFT': {'quantity': 2, 'option': 'MSFT-20240816-480.0-C'},
  'AMZN': {'quantity': 2, 'option': 'AMZN-20250321-205.0-C'},
  'GOOGL': {'quantity': 0.0, 'option': None},
  'AAPL': {'quantity': 0.0, 'option': None},
  'datetime': '2024-03-06'},
 {'AMD': {'quantity': 2, 'option': 'AMD-20240816-270.0-C'},
  'MSFT': {'quantity': 2, 'option': 'MSFT-20240816-480.0-C'},
  'AMZN': {'quantity': 2, 'option': 'AMZN-20250321-205.0-C'},
  'GOOGL': {'quantity': 0.0, 'option': None},
  'AAPL': {'quantity': 0.0, 'option': None},
  'datetime': '2024-03-07'},
 {'AMD': {'quantity': 2, 'option': 'AMD-20240816-270.0-C'},
  'MSFT': {'quantity': 2, 'option': 'MSFT-20240816-480.0-C'},
  'AMZN': {'quantity': 2, 'option': 'AMZN-20250321-205.0-C'},
  'GOOGL': {'quantity': 0.0, 'option': None},
  'AAPL': {'quantity': 0.0, 'option': None},
  'datetime': '2024-03-08'}]

trade_data = []
option_ids = []
for option in options: 
  for option_data_key, option_data_value in option.items(): 
    if option_data_key != 'datetime':
      if option_data_value['option'] is not None:
        print(option_data_key, option_data_value)
        option_ids.append(option_data_value['option'])
        option_id = option_data_value['option']
        fist_entry_price_occur = next((data for data in options if data[option_data_key]['option'] == option_id and 'entry_price' in data[option_data_key]), None)
        entry_price = fist_entry_price_occur[option_data_key]['entry_price'] if fist_entry_price_occur is not None else None
        first_exit_price_occur = next((data for data in options if data[option_data_key]['option'] == option_id and 'exit_price' in data[option_data_key]), None)
        exit_price = first_exit_price_occur[option_data_key]['exit_price'] if first_exit_price_occur is not None else None
        pnl = exit_price - entry_price if exit_price is not None and entry_price is not None else None
# Out:
# AMD {'quantity': 2, 'option': 'AMD-20240816-270.0-C', 'entry_price': 120}
# {'AMD': {'quantity': 2, 'option': 'AMD-20240816-270.0-C', 'entry_price': 120}, 'MSFT': {'quantity': 2, 'option': 'MSFT-20240816-480.0-C'}, 'AMZN': {'quantity': 2, 'option': 'AMZN-20250321-205.0-C'}, 'GOOGL': {'quantity': 0.0, 'option': None}, 'AAPL': {'quantity': 0.0, 'option': None}, 'datetime': '2024-03-05'}
# MSFT {'quantity': 2, 'option': 'MSFT-20240816-480.0-C'}
# None
# AMZN {'quantity': 2, 'option': 'AMZN-20250321-205.0-C'}
# None
# AMD {'quantity': 2, 'option': 'AMD-20240816-270.0-C', 'entry_price': 140}
# {'AMD': {'quantity': 2, 'option': 'AMD-20240816-270.0-C', 'entry_price': 120}, 'MSFT': {'quantity': 2, 'option': 'MSFT-20240816-480.0-C'}, 'AMZN': {'quantity': 2, 'option': 'AMZN-20250321-205.0-C'}, 'GOOGL': {'quantity': 0.0, 'option': None}, 'AAPL': {'quantity': 0.0, 'option': None}, 'datetime': '2024-03-05'}
# MSFT {'quantity': 2, 'option': 'MSFT-20240816-480.0-C'}
# None
# AMZN {'quantity': 2, 'option': 'AMZN-20250321-205.0-C'}
# None
# AMD {'quantity': 2, 'option': 'AMD-20240816-270.0-C'}
# {'AMD': {'quantity': 2, 'option': 'AMD-20240816-270.0-C', 'entry_price': 120}, 'MSFT': {'quantity': 2, 'option': 'MSFT-20240816-480.0-C'}, 'AMZN': {'quantity': 2, 'option': 'AMZN-20250321-205.0-C'}, 'GOOGL': {'quantity': 0.0, 'option': None}, 'AAPL': {'quantity': 0.0, 'option': None}, 'datetime': '2024-03-05'}
# MSFT {'quantity': 2, 'option': 'MSFT-20240816-480.0-C'}
# None
# AMZN {'quantity': 2, 'option': 'AMZN-20250321-205.0-C'}
# None
# AMD {'quantity': 2, 'option': 'AMD-20240816-270.0-C'}
# {'AMD': {'quantity': 2, 'option': 'AMD-20240816-270.0-C', 'entry_price': 120}, 'MSFT': {'quantity': 2, 'option': 'MSFT-20240816-480.0-C'}, 'AMZN': {'quantity': 2, 'option': 'AMZN-20250321-205.0-C'}, 'GOOGL': {'quantity': 0.0, 'option': None}, 'AAPL': {'quantity': 0.0, 'option': None}, 'datetime': '2024-03-05'}
# MSFT {'quantity': 2, 'option': 'MSFT-20240816-480.0-C'}
# None
# AMZN {'quantity': 2, 'option': 'AMZN-20250321-205.0-C'}
# None

# %%
{}.items()
# Out:
#   Cell In[40], line 1
#     {}.items()?
#               ^
# SyntaxError: invalid syntax
